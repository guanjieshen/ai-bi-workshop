-- %%
-- All Enbridge incidents with key details
SELECT 
*
FROM gshen_catalog.enbridge_sr_workshop.accident_hazardous_liquid_jan_2010_present
WHERE NAME LIKE '%ENBRIDGE%'
:param_1
-- Out:
-- Databricks visualization. Run in Databricks to view.
