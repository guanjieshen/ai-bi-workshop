# %%
# %pip install dbdemos

# %%
# %sql CREATE SCHEMA IF NOT EXISTS gshen_catalog.dbdemos_aibi_mfg_supply_chain_optimization

# %%
import dbdemos
dbdemos.install('aibi-supply-chain-forecasting', catalog='gshen_catalog', schema='dbdemos_aibi_mfg_supply_chain_optimization')
