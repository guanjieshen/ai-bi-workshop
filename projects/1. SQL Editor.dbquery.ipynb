-- %%
SELECT * FROM actuals_sap;
SELECT * FROM change_orders;


-- We can also use Databricks assistant built in to help us generate SQL code.
/* Using the actuals_sap table show monthly spend by project and cost type (material vs. labor) */
SELECT
  `Project ID`,
  Month,
  SUM(`Material Cost ($)`) AS material_spend,
  SUM(`Labor Cost ($)`) AS labor_spend
FROM
  actuals_sap
GROUP BY
  `Project ID`,
  Month
ORDER BY
  `Project ID`,
  Month

-- Once we have a table, we can use the UI to add some customization to the visuals directly in the SQL editor.

-- We can also download the source data as a CSV or Excel file and the visualization as image.

-- We can save this query directly our workspace and also share this other team members.

-- There's also native collaboration features built directly in the web application: comments, version control

-- We can also add automation to our queries i.e. schedules
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
